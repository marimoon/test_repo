# %% [markdown]
# # Subject1

# %% [markdown]
# This is a comment area.

# %%
1 + 2
# Out:
# 3

# %%
import matplotlib
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,11,0.05)
s = 1.0
u = 5
y = np.exp( -(x-u)*(x-u)*0.5/s/s)
plt.plot(x, y)
plt.show()
