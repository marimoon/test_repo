# %%
try:
    mp = '/content/drive'
    from google.colab import drive
    drive.mount(mp)
    import os
    os.chdir( mp + '/My Drive/Colab Notebooks' )
    g_dir_work = os.getcwd()
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline

# %% [markdown]
# ### pretrainなし

# %%
# !python app_pix2pixgan_train.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0826 15:39:39.388308 140154975438720 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model_pix2pix_gan__generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, None, None, 1)]   0
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, None, 1)     4
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 200)   5200
# ...

# %% [markdown]
# ### pretrainあり
#
# generator・discriminatorモデルのpretrain後、ganモデルを最適化

# %%
# !python app_pix2pixgan_train.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0826 16:13:06.420006 139658965727104 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model_pix2pix_gan__generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, None, None, 1)]   0
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, None, 1)     4
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 200)   5200
# ...
